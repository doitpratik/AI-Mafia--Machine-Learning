# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
#
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```
#
#
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
# import pandas
import pandas as pd

# %% [markdown]
# >The `imdb.csv` dataset contains Highest Rated IMDb "Top 1000" Titles.

# %%
# load imdb dataset as pandas dataframe
imdb_df=pd.DataFrame(pd.read_csv(r'C:\Users\OM SAI\Downloads\imdb_1000.csv'))
imdb_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# show first 5 rows of imdb_df
imdb_df.head() #by default the head command prints the sfive rows
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# >The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012.

# %%
# load bikes dataset as pandas dataframe
bikedf=pd.read_csv(r"C:\Users\OM SAI\Downloads\bikes.csv", sep=';',parse_dates=['Date'])
bikedf
# Out:
#           Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0   2012-01-01      00:00                 16      35             51
# 1   2012-02-01      00:00                 43      83            153
# 2   2012-03-01      00:00                 58     135            248
# 3   2012-04-01      00:00                 61     144            318
# 4   2012-05-01      00:00                 95     197            330
# ..         ...        ...                ...     ...            ...
# 361 2012-12-27      00:00                  8      12              7
# 362 2012-12-28      00:00                  0      35              3
# 363 2012-12-29      00:00                  0      27              8
# 364 2012-12-30      00:00                  0       5              1
# 365 2012-12-31      00:00                  0       4              3
#
#      Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0               38      5.0    26       10                            0
# ...

# %%
# show first 3 rows of bikes_df
bikedf.head((3))
# Out:
#            Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# Date
# 2012-01-01      00:00                 16      35             51
# 2012-01-02      00:00                 43      83            153
# 2012-01-03      00:00                 58     135            248
#
#             Maisonneuve_1  BrÃ©beuf  Parc  PierDup  \
# Date
# 2012-01-01             38       5.0    26       10
# 2012-01-02             68      11.0    53        6
# 2012-01-03            104       2.0    89        3
#
#             CSC (CÃ´te Sainte-Catherine)  Pont_Jacques_Cartier
# Date
# 2012-01-01                             0                  27.0
# 2012-01-02                             1                  21.0
# 2012-01-03                             2                  15.0

# %% [markdown]
# ## Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
# list columns of imdb_df
a=list(imdb_df.columns)
print(a)
imdb_df.keys()
# Out:
# ['star_rating', 'title', 'content_rating', 'genre', 'duration', 'actors_list']
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# what are the datatypes of values in columns
imdb_df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# list first 5 movie titles
imdb_df['title'].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
# show only movie title and genre
imdb_df[['title','genre']]
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
# show the type of duration column
import numpy as np
a=imdb_df.dtypes['duration']
b=type(imdb_df['duration'])
print(a)
print(b)
# Out:
# int64
# <class 'pandas.core.series.Series'>

# %%
# show duration values of movies as numpy arrays
c=np.array(imdb_df['duration'])
print(c)
# Out:
# [142 175 200 152 154  96 161 201 195 139 178 148 124 142 179 169 133 207
#  146 121 136 130 130 106 127 116 175 118 110  87 125 112 102 107 119  87
#  169 115 112 109 189 110 150 165 155 137 113 165  95 151 155 153 125 130
#  116  89 137 117  88 165 170  89 146  99  98 116 156 122 149 134 122 136
#  157 123 119 137 128 120 229 107 134 103 177 129 102 216 136  93  68 189
#   99 108 113 181 103 138 110 129  88 160 126  91 116 125 143  93 102 132
#  153 183 160 120 138 140 153 170 129  81 127 131 172 115 108 107 129 156
#   96  91  95 162 130  86 186 151  96 170 118 161 131 126 131 129 224 180
#  105 117 140 119 124 130 139 107 132 117 126 122 178 238 149 172  98 116
#  116 123 148 123 182  92  93 100 135 105  94 140  83  95  98 143  99  98
#  121 163 121 167 188 121 109 110 129 127  94 107 100 117 129 120 121 133
#  111 122 101 134 165 138 212 154  89 134  93 114  88 130 101 158  99 108
#  124 132 113 131 191 167 130 147 102  88 165 132 118 101 108 174  98  92
# ...

# %% [markdown]
# ## Applying functions to columns
#
# Use `.apply` function to apply any function to each element of a column.

# %%
# convert all the movie titles to uppercase
#imdbdf['title'].str.upper()
imdb_df['title'].apply(lambda x:x.upper()).head()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# plot the bikers travelling to Berri1 over the year
import matplotlib.pyplot as plt

#fixed_df = pd.read_csv(r'C:\Users\OM SAI\Downloads\bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#fixed_df['Berri1'].plot()
plt.plot(bikedf['Berri1'])

# %%
# plot all the columns of bikes_df
bikedf.plot(subplots=True,layout=(3,4),figsize=(20, 10))
plt.show()

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
# what are the unique genre in imdb_df?
imdb_df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
# plotting value counts of unique genres as a bar chart
imdbdf['genre'].value_counts().plot(kind='bar', title='Genres')

# %%
# plotting value counts of unique genres as a pie chart
imdbdf['genre'].value_counts().plot(kind='pie', radius=2,title='Genres', startangle=45,autopct='%1.1f%%', figsize=((10,5))).legend()

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
# show index of bikes_df

bikedf.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
##### get row for date 2012-01-01
bikedf[bikedf['Date']=='2012-01-01']
# Out:
#         Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0 2012-01-01      00:00                 16      35             51
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
#
#    Pont_Jacques_Cartier
# 0                  27.0

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
# show 11th row of imdb_df using iloc
imdb_df.iloc[11]
# Out:
# star_rating                                                     8.8
# title                                                     Inception
# content_rating                                                PG-13
# genre                                                        Action
# duration                                                        148
# actors_list       [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# Name: 11, dtype: object

# %% [markdown]
# ## Selecting rows where column has a particular value

# %%
# select only those movies where genre is adventure
imdb_df[imdb_df.genre =='Adventure']
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 54           8.5                                 Back to the Future
# ..           ...                                                ...
# 936          7.4                                          True Grit
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?
print('The Higest Genre with star rating above 8 and duration more than 130 minutes:')
imdb_df[(imdb_df.star_rating > 8)&(imdb_df.duration > 130)]['genre'].max()
# Out:
# The Higest Genre with star rating above 8 and duration more than 130 minutes:
# 'Western'

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
# add a weekday column to bikes_df
bikedf['weekday']=bikedf['Date'].apply(lambda y: y.dayofweek)
#sr = pd.Series(pd.date_range('2012-01-02 12:12', periods = 5, freq = 'M')) 
  
# Creating the index 
#idx = ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5'] 
  
# set the index 
#sr.index = idx 
bikedf
# Out:
#           Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0   2012-01-01      00:00                 16      35             51
# 1   2012-02-01      00:00                 43      83            153
# 2   2012-03-01      00:00                 58     135            248
# 3   2012-04-01      00:00                 61     144            318
# 4   2012-05-01      00:00                 95     197            330
# ..         ...        ...                ...     ...            ...
# 361 2012-12-27      00:00                  8      12              7
# 362 2012-12-28      00:00                  0      35              3
# 363 2012-12-29      00:00                  0      27              8
# 364 2012-12-30      00:00                  0       5              1
# 365 2012-12-31      00:00                  0       4              3
#
#      Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0               38      5.0    26       10                            0
# ...

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
# remove column 'Unnamed: 1' from bikes_df
bikedf.drop('Unnamed: 1',axis=1, inplace=True)
print(bikedf)
# Out:
#           Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0   2012-01-01                 16      35             51             38
# 1   2012-02-01                 43      83            153             68
# 2   2012-03-01                 58     135            248            104
# 3   2012-04-01                 61     144            318            116
# 4   2012-05-01                 95     197            330            124
# ..         ...                ...     ...            ...            ...
# 361 2012-12-27                  8      12              7              4
# 362 2012-12-28                  0      35              3             38
# 363 2012-12-29                  0      27              8             42
# 364 2012-12-30                  0       5              1              5
# 365 2012-12-31                  0       4              3              8
#
#      Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
# remove row no. 1 from bikes_df
bikedf.drop(1,axis=0,inplace=True)
print(bikedf)
# Out:
#           Date  Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0   2012-01-01                 16      35             51             38
# 2   2012-03-01                 58     135            248            104
# 3   2012-04-01                 61     144            318            116
# 4   2012-05-01                 95     197            330            124
# 5   2012-06-01                 75     146            244             98
# ..         ...                ...     ...            ...            ...
# 361 2012-12-27                  8      12              7              4
# 362 2012-12-28                  0      35              3             38
# 363 2012-12-29                  0      27              8             42
# 364 2012-12-30                  0       5              1              5
# 365 2012-12-31                  0       4              3              8
#
#      Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# ...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
# group imdb_df by movie genres

imdb_df.groupby(['genre'])

# %%
    # get crime movies group
imdbdf.groupby(['genre']).get_group('Crime')
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
# get mean of movie durations for each group
b=imdb_df.groupby(['genre']).mean()
b['duration']
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
# change duration of all movies in a particular genre to mean duration of the group
my_crime=imdb_df.groupby('genre').get_group('Crime')
my_crime['duration']=my_crime['duration'].mean()
my_crime[['title','duration']]
# Out:
# C:\Users\OM SAI\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         title    duration
# 0    The Shawshank Redemption  122.298387
# 1               The Godfather  122.298387
# 2      The Godfather: Part II  122.298387
# 4                Pulp Fiction  122.298387
# 21                City of God  122.298387
# ..                        ...         ...
# 927                     Brick  122.298387
# 931              Mean Streets  122.298387
# 950                     Bound  122.298387
# 969       Law Abiding Citizen  122.298387
# 978               Wall Street  122.298387
#
# ...

# %%
# drop groups/genres that do not have average movie duration greater than 120.
imdb_df.groupby('genre').filter(lambda a:a['duration'].mean() >float(120))
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# group weekday wise bikers count
v=bikedf.groupby('weekday').sum()

# %%
# get weekday wise biker count
print(v)
# Out:
#          Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  Brébeuf  \
# weekday
# 0                   134966  140206         173675          96247  15976.0
# 1                   128109  132563         162262          89861  10644.0
# 2                   141436  156540         190065         106485  14935.0
# 3                   147325  158044         190903         109796  16227.0
# 4                   149402  155651         188838         106005  10019.0
# 5                   130158  123719         132358          77071  10171.0
# 6                   122230  113428         122742          67324  14098.0
#
#            Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier
# weekday
# 0         95962    42152                        61397               68785.0
# 1         89884    37330                        58033               51967.0
# 2        104338    45891                        68486               61058.0
# ...

# %%
# plot weekday wise biker count for 'Berri1'
plt.plot(v['Berri1'], color='Orange')
plt.show()
plt.close()

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
